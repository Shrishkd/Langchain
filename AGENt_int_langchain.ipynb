# %%
import os
os.environ["GOOGLE_API_KEY"] = "AQ.Ab8RN6ImZj347vL_N3vR6gk9oknMl92DZhIFQ0EmrOtQW8d1q" # Please ensure this is your actual Google API Key

# %%
# !pip install -q langchain-google-genai langchain-community langchain-core requests duckduckgo-search ddgs
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.6/47.6 kB 2.8 MB/s eta 0:00:00

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.tools import tool
import requests
from langchain_community import hub # Corrected import for hub
from langchain.agents import create_react_agent, AgentExecutor
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_2393/1792955539.py in <cell line: 0>()
#       2 from langchain_core.tools import tool
#       3 import requests
# ----> 4 from langchain_community import hub # Corrected import for hub
#       5 from langchain.agents import create_react_agent, AgentExecutor
#
# ImportError: cannot import name 'hub' from 'langchain_community' (/usr/local/lib/python3.13/dist-packages/langchain_community/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from langchain_community.tools import DuckDuckGoSearchRun

search_tool = DuckDuckGoSearchRun()

# %%
from langchain_community.tools import DuckDuckGoSearchRun

search_tool = DuckDuckGoSearchRun()

# %%
@tool
def get_weather_data(city: str) -> str:
  """
  This function fetches the current weather data for a given city
  """
  url = f'https://api.weatherstack.com/current?access_key=88e2419a08866dfdb1364366cfb0aa8d&query={city}'

  response = requests.get(url)

  return response.json()

# %%
llm = ChatGoogleGenerativeAI(model="gemini-3.6-flash", google_api_key=os.environ["GOOGLE_API_KEY"])

# %%
# Step 2: Pull the ReAct prompt from LangChain Hub
prompt = hub.pull("hwchase17/react")  # pulls the standard ReAct agent prompt
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2393/3720386481.py in <cell line: 0>()
#       1 # Step 2: Pull the ReAct prompt from LangChain Hub
# ----> 2 prompt = hub.pull("hwchase17/react")  # pulls the standard ReAct agent prompt
#
# NameError: name 'hub' is not defined

# %%
tools = [
    search_tool,
    get_weather_data
]

# %%
# Step 3: Create the ReAct agent manually with the pulled prompt
agent = create_react_agent(
    llm=llm,
    tools=[search_tool, get_weather_data],
    prompt=prompt
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2393/3152641312.py in <cell line: 0>()
#       1 # Step 3: Create the ReAct agent manually with the pulled prompt
# ----> 2 agent = create_react_agent(
#       3     llm=llm,
#       4     tools=[search_tool, get_weather_data],
#       5     prompt=prompt
#
# NameError: name 'create_react_agent' is not defined

# %%
# Step 4: Wrap it with AgentExecutor
agent_executor = AgentExecutor(
    agent=agent,
    tools=[search_tool, get_weather_data],
    verbose=True
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2393/2527489542.py in <cell line: 0>()
#       1 # Step 4: Wrap it with AgentExecutor
# ----> 2 agent_executor = AgentExecutor(
#       3     agent=agent,
#       4     tools=[search_tool, get_weather_data],
#       5     verbose=True
#
# NameError: name 'AgentExecutor' is not defined

# %%
# Step 5: Invoke
response = agent_executor.invoke({"input": "Find the capital of Madhya Pradesh, then find it's current weather condition"})
print(response)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2393/2029315389.py in <cell line: 0>()
#       1 # Step 5: Invoke
# ----> 2 response = agent_executor.invoke({"input": "Find the capital of Madhya Pradesh, then find it's current weather condition"})
#       3 print(response)
#
# NameError: name 'agent_executor' is not defined

# %%
response['output']
